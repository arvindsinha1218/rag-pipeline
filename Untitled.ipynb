# %%
import sys

# !{sys.executable} -m pip install pinecone \
langchain \
langchain-core \
langchain-community \
langchain-openai \
langchain-google-genai \
langchain-huggingface \
sentence-transformers \
scikit-learn \
beautifulsoup4 \
docx2txt \
pypdf \
openai \
google-generativeai
# Out:
# ...
#   Using cached pinecone-9.0.0-cp310-abi3-win_amd64.whl.metadata (5.2 kB)
# ...
#   Using cached langchain_core-1.4.0-py3-none-any.whl.metadata (4.5 kB)
# ...
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached langchain_google_genai-4.2.2-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached langchain_huggingface-1.2.2-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached langchain_protocol-0.0.15-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached langsmith-0.8.5-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached langchain_classic-1.0.7-py3-none-any.whl.metadata (5.1 kB)
# ...

# %%
# !pip install --upgrade jupyter ipywidgets notebook tqdm
# Out:
# ...
#   Using cached notebook-7.5.6-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached rfc3987_syntax-1.1.0-py3-none-any.whl.metadata (7.7 kB)
# ...
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# ...
#   Using cached webcolors-25.10.0-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached lark-1.3.1-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached arrow-1.4.0-py3-none-any.whl.metadata (7.7 kB)
# ...
#   Using cached tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ---------------------------------- ----- 786.4/914.9 kB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 914.9/914.9 kB 3.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
# ...
